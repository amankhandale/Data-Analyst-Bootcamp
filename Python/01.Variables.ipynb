# %% [markdown]
# Variables in Python

# %%
x = 25
print(x)
# Out:
# 25
# 3.7

# %%
type(x)
# Out:
# int

# %%
y = ("Chocolate")
print(y)
# Out:
# Chocolate

# %%
type(y)
# Out:
# str

# %%
x,y,z = 'vanilla','chocolate','blueberry'
print(y,x,z)
# Out:
# chocolate vanilla blueberry

# %%
x = y = z = 'Boiled Eggs'
print(y)
print(x)
print(z)
# Out:
# Boiled Eggs
# Boiled Eggs
# Boiled Eggs

# %%
ice_cream = ('vanilla','chocolate','blueberry')
x,y,z = ice_cream

print(y)
print(x)
print(z)
# Out:
# chocolate
# vanilla
# blueberry

# %%
# Camel Case  (most used without space)

#test Variable Case

testVariableCase = 'Vanilla Swirl'

# %%
# Pascel Case
# Test variable Case
TestvariableCase = 'Chocolate Swirl'

# %%
# Snake Case   (more readable)
#Test Variable Case
test_variable_case = 'BlueBerry Swirl'

# %%
x = 'Ice Cream is my favorite' + '.'
print(x)
# Out:
# Ice Cream is my favorite.

# %%
x = 'Ice Cream'
y = ' is'
z = ' my favourite'
print(x+y+z)
# Out:
# Ice Cream is my favourite

# %%
x = 1
y = 2
z = 3

print(x+y+z)
# Out:
# 6

# %%
x = 'Ice Cream'
y = 8
print(x,y)
# Out:
# Ice Cream 8
